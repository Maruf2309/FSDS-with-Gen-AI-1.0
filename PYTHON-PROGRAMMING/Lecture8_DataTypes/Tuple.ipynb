# %% [markdown]
# # Day 8 : Tuple

# %% [markdown]
# # Tuples
#
# A tuple in Python is `similar to a list`. The difference between the two is that we `cannot change the elements of a tuple` once it is assigned whereas `we can change the elements of a list`.
#
# In short, a tuple is an `immutable list`. A tuple can not be changed in any way once it is created.
#
# Characterstics
#
# - Ordered
# - Unchangeble
# - Allows duplicate
#
#
# ### Topic to be discussed
#
# - Creating a Tuple
# - Accessing items
# - Editing items
# - Adding items
# - Deleting items
# - Operations on Tuples
# - Tuple Functions

# %% [markdown]
# A tuple in Python is an ordered, immutable collection of items. It is a built-in data type used to store multiple items in a single variable.

# %% [markdown]
# **Creating Tuple**

# %%
l = []

# %%
#empty tuple
t1 = ()
print(t1)
print(type(t1))
# Out:
# ()
# <class 'tuple'>

# %%
# # create a tuple with a single item
t = ("Maruf")
print(t)
print(type(t))
# Out:
# Maruf
# <class 'str'>

# %%
# homo
t1 = (1, 2, 3, 4)

# hetro
t2 = (1, 2, 3, True, [1,2,3])

# Nested
t3 = (1, 2, 3,(4, 5))

# Using type Conversion
t4 = tuple("hello")

print(t1)
print(t2)
print(t3)
print(t4)
# Out:
# (1, 2, 3, 4)
# (1, 2, 3, True, [1, 2, 3])
# (1, 2, 3, (4, 5))
# ('h', 'e', 'l', 'l', 'o')

# %% [markdown]
# ## Accessing Items

# %% [markdown]
# - Indexing
# - Slicing
