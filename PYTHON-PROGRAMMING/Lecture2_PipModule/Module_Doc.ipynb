# %% [markdown]
# # Modules (Package) in Python

# %% [markdown]
# Module - Must be imported

# %% [markdown]
# https://docs.python.org/3/py-modindex.html

# %% [markdown]
# 1. BuitdIns / Package
# 2. External / Package
#
# **Built Ins Modules**
# - math
# - keyword
# - random
# - datetime

# %% [markdown]
# ✅ Commonly Used Python Modules & Packages

# %% [markdown]
# | Module         | Purpose                                          |
# | -------------- | ------------------------------------------------ |
# | **math**       | Mathematical functions (sqrt, pi, sin, cos, log) |
# | **random**     | Random numbers, choices, shuffle                 |
# | **statistics** | Mean, median, stdev                              |
# | **fractions**  | Fraction arithmetic                              |
# | **decimal**    | High-precision decimal arithmetic                |

# %% [markdown]
# 📅 2. Date & Time

# %% [markdown]
# | Module       | Purpose                            |
# | ------------ | ---------------------------------- |
# | **datetime** | Date, time, timedelta, formatting  |
# | **time**     | System time, sleep(), time stamps  |
# | **calendar** | Calendar formatting & calculations |

# %% [markdown]
# 📝 3. Text Processing

# %% [markdown]
# | Module       | Purpose                                       |
# | ------------ | --------------------------------------------- |
# | **string**   | String constants (ascii_letters, punctuation) |
# | **re**       | Regular expressions                           |
# | **textwrap** | Formatting text (wrap, indent)                |
# | **json**     | Working with JSON data                        |
# | **csv**      | CSV file reading/writing                      |

# %% [markdown]
# 🗂️ 4. System & OS

# %% [markdown]
# | Module         | Purpose                                         |
# | -------------- | ----------------------------------------------- |
# | **os**         | File system, environment variables              |
# | **sys**        | System-specific parameters; `sys.argv`, version |
# | **shutil**     | High-level file operations (copy, move, remove) |
# | **pathlib**    | Modern, object-oriented file paths              |
# | **subprocess** | Run external commands                           |

# %% [markdown]
# 📦 5. Python Interpreter & Code Tools

# %% [markdown]
# | Module        | Purpose                                        |
# | ------------- | ---------------------------------------------- |
# | **keyword**   | List of Python keywords                        |
# | **builtins**  | Access built-in functions                      |
# | **importlib** | Import modules dynamically                     |
# | **inspect**   | Inspect functions, classes, modules at runtime |

# %% [markdown]
# 🌐 6. Networking & Web

# %% [markdown]
# | Module                  | Purpose                    |
# | ----------------------- | -------------------------- |
# | **urllib**              | URL handling               |
# | **http**                | HTTP client & server tools |
# | **socket**              | Low-level networking       |
# | **requests (external)** | Easy HTTP requests         |

# %% [markdown]
# 🧵 7. Concurrency & Parallelism

# %% [markdown]
# | Module              | Purpose                  |
# | ------------------- | ------------------------ |
# | **threading**       | Threads                  |
# | **multiprocessing** | Parallel processing      |
# | **asyncio**         | Asynchronous programming |

# %% [markdown]
# 🗃️ 8. Data Storage

# %% [markdown]
# | Module      | Purpose                             |
# | ----------- | ----------------------------------- |
# | **sqlite3** | SQLite database engine              |
# | **pickle**  | Serialize Python objects            |
# | **dbm**     | Simple file-based key-value storage |

# %% [markdown]
# 🔐 9. Security

# %% [markdown]
# | Module      | Purpose                             |
# | ----------- | ----------------------------------- |
# | **hashlib** | Hashing algorithms (MD5, SHA)       |
# | **secrets** | Cryptographic secure random numbers |
# | **crypt**   | Password hashing (Unix only)        |

# %% [markdown]
# 🎨 10. GUI & Graphics

# %% [markdown]
# | Module      | Purpose          |
# | ----------- | ---------------- |
# | **tkinter** | Built-in GUI     |
# | **turtle**  | Drawing graphics |

# %% [markdown]
# 🧰 BONUS: Highly Useful External Packages

# %% [markdown]
# | Package                  | Purpose                   |
# | ------------------------ | ------------------------- |
# | **numpy**                | Numerical computing       |
# | **pandas**               | Data analysis             |
# | **matplotlib**           | Plotting                  |
# | **seaborn**              | Statistical visualization |
# | **scikit-learn**         | Machine learning          |
# | **tensorflow / pytorch** | Deep learning             |
# | **flask / django**       | Web development           |
# | **fastapi**              | Modern web APIs           |
# | **beautifulsoup4**       | Web scraping              |
